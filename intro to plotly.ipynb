# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Data
df = pd.DataFrame(np.random.randn(100,4),columns=['A','B','C','D'])

# %%
df.head()
# Out:
#           A         B         C         D
# 0  1.944463 -0.806243  0.793593  1.814021
# 1 -0.612978 -0.417253 -2.047968  1.480026
# 2 -0.827198 -0.842285  2.617600 -1.800023
# 3 -0.737460  0.586381 -0.204689 -0.859769
# 4 -0.332232  0.870760  0.686270  1.381608

# %%
df2 = pd.DataFrame({'Category':'A B C'.split(),'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.iplot()
# Out:
# <div>
#
#
#             <div id="dcc6bf52-d45a-42c6-901d-c8f3b2177e55" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("dcc6bf52-d45a-42c6-901d-c8f3b2177e55")) {
#                     Plotly.newPlot(
#                         'dcc6bf52-d45a-42c6-901d-c8f3b2177e55',
# ...

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=10)
# Out:
# <div>
#
#
#             <div id="04e3ef1a-1a90-4dc4-83b8-be12751e2812" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("04e3ef1a-1a90-4dc4-83b8-be12751e2812")) {
#                     Plotly.newPlot(
#                         '04e3ef1a-1a90-4dc4-83b8-be12751e2812',
# ...

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>
#
#
#             <div id="997956c4-7f4e-4cd1-bab1-69b3c943a148" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("997956c4-7f4e-4cd1-bab1-69b3c943a148")) {
#                     Plotly.newPlot(
#                         '997956c4-7f4e-4cd1-bab1-69b3c943a148',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df
# Out:
#            A         B         C         D
# 0  -1.575036  1.810706  1.460593 -1.047666
# 1  -1.094488 -2.033294 -0.271095 -0.232605
# 2  -0.455923 -0.316499  0.486932 -0.448895
# 3  -2.331365  0.577027  1.055033  1.551448
# 4  -0.554590  0.564210 -0.686109  1.459484
# ..       ...       ...       ...       ...
# 95 -1.299901 -0.706927 -1.851809 -2.204592
# 96 -0.493695 -0.585040 -0.010737 -0.104208
# 97 -0.002661 -0.920297 -0.759899 -0.785368
# 98 -0.427506  0.688023 -0.390772 -0.329741
# 99 -1.543631 -0.418627 -1.672911  0.795293
#
# [100 rows x 4 columns]

# %%
df.iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="46a210cd-75da-4ec0-8a75-e1bc36dfa0b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("46a210cd-75da-4ec0-8a75-e1bc36dfa0b4")) {
#                     Plotly.newPlot(
#                         '46a210cd-75da-4ec0-8a75-e1bc36dfa0b4',
# ...

# %%
df.count().iplot(kind='bar') #equally distributed
# Out:
# <div>
#
#
#             <div id="88c36d69-940b-4595-9322-ac25aeb12a77" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("88c36d69-940b-4595-9322-ac25aeb12a77")) {
#                     Plotly.newPlot(
#                         '88c36d69-940b-4595-9322-ac25aeb12a77',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [100, 100, 100, 100]}],
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="3f50a7b1-ca34-454d-b7e3-b25bc5368454" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3f50a7b1-ca34-454d-b7e3-b25bc5368454")) {
#                     Plotly.newPlot(
#                         '3f50a7b1-ca34-454d-b7e3-b25bc5368454',
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})

# %%
df3.iplot(kind='surface',color='rdylbu')
# Out:
# <div>
#
#
#             <div id="33f836d1-fa3f-4921-8543-b4260ea7852d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("33f836d1-fa3f-4921-8543-b4260ea7852d")) {
#                     Plotly.newPlot(
#                         '33f836d1-fa3f-4921-8543-b4260ea7852d',
# ...

# %%
df['A'].iplot(kind='hist',bins=25)
# Out:
# <div>
#
#
#             <div id="6e6b3ffb-fffe-40d3-b68e-cf88b9a5d18f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6e6b3ffb-fffe-40d3-b68e-cf88b9a5d18f")) {
#                     Plotly.newPlot(
#                         '6e6b3ffb-fffe-40d3-b68e-cf88b9a5d18f',
# ...

# %%
df.iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="2d91e3e1-48d9-42bc-b4c7-040b41b50781" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2d91e3e1-48d9-42bc-b4c7-040b41b50781")) {
#                     Plotly.newPlot(
#                         '2d91e3e1-48d9-42bc-b4c7-040b41b50781',
# ...

# %%
df[['A','B']].iplot(kind='spread') #used in financial data comparing
# Out:
# <div>
#
#
#             <div id="1d0485e4-78dc-47ab-a3f0-6972fb38ae6a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1d0485e4-78dc-47ab-a3f0-6972fb38ae6a")) {
#                     Plotly.newPlot(
#                         '1d0485e4-78dc-47ab-a3f0-6972fb38ae6a',
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>
#
#
#             <div id="64d5dea2-3e3e-470b-b729-c3d802252cef" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("64d5dea2-3e3e-470b-b729-c3d802252cef")) {
#                     Plotly.newPlot(
#                         '64d5dea2-3e3e-470b-b729-c3d802252cef',
# ...

# %%
df.scatter_matrix()
#used only on numerical data
# Out:
# <div>
#
#
#             <div id="fd15faa4-7065-4c0f-8642-9d2eb6ab5dd2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fd15faa4-7065-4c0f-8642-9d2eb6ab5dd2")) {
#                     Plotly.newPlot(
#                         'fd15faa4-7065-4c0f-8642-9d2eb6ab5dd2',
# ...
